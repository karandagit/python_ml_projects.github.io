# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matches = pd.read_csv("matches.csv",encoding="latin1")

# %%
matches.shape
# Out:
# (756, 18)

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
pd.value_counts(matches['winner']).plot(kind="bar",alpha=0.5)

# %%
pd.value_counts(matches['season'])
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
matches.drop_duplicates('season',keep='last')[['season','winner']].reset_index(drop=True)
# Out:
#     season                 winner
# 0     2017         Mumbai Indians
# 1     2008       Rajasthan Royals
# 2     2009        Deccan Chargers
# 3     2010    Chennai Super Kings
# 4     2011    Chennai Super Kings
# 5     2012  Kolkata Knight Riders
# 6     2013         Mumbai Indians
# 7     2014  Kolkata Knight Riders
# 8     2015         Mumbai Indians
# 9     2016    Sunrisers Hyderabad
# 10    2018    Chennai Super Kings
# 11    2019         Mumbai Indians

# %%
matches[matches['player_of_match']=='MS Dhoni'][['team1','team2','season','player_of_match']]
# Out:
#                            team1                        team2  season  \
# 24           Sunrisers Hyderabad       Rising Pune Supergiant    2017
# 73           Chennai Super Kings  Royal Challengers Bangalore    2008
# 86              Delhi Daredevils          Chennai Super Kings    2008
# 143          Chennai Super Kings              Deccan Chargers    2009
# 181          Chennai Super Kings        Kolkata Knight Riders    2010
# 227              Kings XI Punjab          Chennai Super Kings    2010
# 288          Chennai Super Kings             Delhi Daredevils    2011
# 378          Chennai Super Kings               Mumbai Indians    2012
# 413          Sunrisers Hyderabad          Chennai Super Kings    2013
# 421          Chennai Super Kings                Pune Warriors    2013
# 445          Chennai Super Kings             Delhi Daredevils    2013
# 509  Royal Challengers Bangalore          Chennai Super Kings    2014
# ...

# %%
pd.value_counts(matches['season']).plot(kind="bar",alpha=0.5)
